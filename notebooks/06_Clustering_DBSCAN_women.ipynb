# %% [markdown]
# # Client segmentation  | Cristiane Carneiro

# %% [markdown]
# Clustering with DBSCAN

# %% [markdown]
# ## Import libraries

# %%
# data
# ==============================================================================
import numpy as np
import pandas as pd

# charts
# ==============================================================================
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits import mplot3d

# pre-processing 
# ==============================================================================
from sklearn.preprocessing import StandardScaler


#from sklearn import metrics
from sklearn.cluster import KMeans, DBSCAN
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.datasets import make_blobs
from sklearn import metrics

# warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

#display
# ==============================================================================
pd.reset_option('display.max_columns')

# %% [markdown]
# ## Import dataset

# %%
data_women = pd.read_csv('../data/data_clean_women.csv')

# %%
data_women.head()
# Out:
#    client_id  residence_country 1  residence_country 2  residence_country 3  \
# 0      76154                    1                    0                    0
# 1     292032                    1                    0                    0
# 2     513675                    1                    0                    0
# 3     514314                    0                    1                    0
# 4     517104                    1                    0                    0
#
#    residence_country 4  residence_country 5  residence_country 6  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    residence_country 7  residence_other region 1  residence_other region 2  \
# 0                    0                         0                         0
# 1                    0                         0                         0
# 2                    0                         0                         0
# 3                    0                         0                         0
# 4                    0                         0                         0
#
#    ...  color_cool_jewel  color_neutral_pastel  color_other  \
# 0  ...                 0                     1            2
# 1  ...                 1                     5            2
# 2  ...                 8                    18            3
# 3  ...                 3                    24           10
# 4  ...                 0                     0            1
#
#    color_vivid_metallic  color_warm_earth  season_autumn  season_spring  \
# 0                     0                 2              4              1
# 1                     1                 3              0              2
# 2                     5                17              6              7
# 3                     4                14             19              0
# 4                     0                 1              0              0
#
#    season_summer  season_winter  total_sum
# 0              0              0          5
# 1             10              0         12
# 2              8             30         51
# 3              2             34         55
# 4              2              0          2
#
# [5 rows x 38 columns]

# %%
data_women.columns
# Out:
# Index(['client_id', 'residence_country 1', 'residence_country 2',
#        'residence_country 3', 'residence_country 4', 'residence_country 5',
#        'residence_country 6', 'residence_country 7',
#        'residence_other region 1', 'residence_other region 2',
#        'residence_other region 3', 'residence_other region 4',
#        'residence_other region 5', 'residence_other region 6',
#        'residence_other region 7', 'residence_other region 8',
#        'generation_gen silent/boomers', 'generation_gen x',
#        'generation_gen z/alpha', 'generation_millennials',
#        'category_children clothes', 'category_handbags',
#        'category_men clothes', 'category_men shoes', 'category_other',
#        'category_soft', 'category_women clothes', 'category_women shoes',
#        'color_cool_jewel', 'color_neutral_pastel', 'color_other',
#        'color_vivid_metallic', 'color_warm_earth', 'season_autumn',
#        'season_spring', 'season_summer', 'season_winter', 'total_sum'],
#       dtype='object')

# %%
data_women_model = data_women.drop(columns=['client_id'],axis=1)
data_women_model.head(2)
# Out:
#    residence_country 1  residence_country 2  residence_country 3  \
# 0                    1                    0                    0
# 1                    1                    0                    0
#
#    residence_country 4  residence_country 5  residence_country 6  \
# 0                    0                    0                    0
# 1                    0                    0                    0
#
#    residence_country 7  residence_other region 1  residence_other region 2  \
# 0                    0                         0                         0
# 1                    0                         0                         0
#
#    residence_other region 3  ...  color_cool_jewel  color_neutral_pastel  \
# 0                         0  ...                 0                     1
# 1                         0  ...                 1                     5
#
#    color_other  color_vivid_metallic  color_warm_earth  season_autumn  \
# 0            2                     0                 2              4
# 1            2                     1                 3              0
#
#    season_spring  season_summer  season_winter  total_sum
# 0              1              0              0          5
# 1              2             10              0         12
#
# [2 rows x 37 columns]

# %%
data_women_model.drop(columns=['total_sum'],axis=1,inplace=True)

# %% [markdown]
# ## Normalization

# %%
data_women_model.columns
# Out:
# Index(['residence_country 1', 'residence_country 2', 'residence_country 3',
#        'residence_country 4', 'residence_country 5', 'residence_country 6',
#        'residence_country 7', 'residence_other region 1',
#        'residence_other region 2', 'residence_other region 3',
#        'residence_other region 4', 'residence_other region 5',
#        'residence_other region 6', 'residence_other region 7',
#        'residence_other region 8', 'generation_gen silent/boomers',
#        'generation_gen x', 'generation_gen z/alpha', 'generation_millennials',
#        'category_children clothes', 'category_handbags',
#        'category_men clothes', 'category_men shoes', 'category_other',
#        'category_soft', 'category_women clothes', 'category_women shoes',
#        'color_cool_jewel', 'color_neutral_pastel', 'color_other',
#        'color_vivid_metallic', 'color_warm_earth', 'season_autumn',
#        'season_spring', 'season_summer', 'season_winter'],
#       dtype='object')

# %%
columns_to_normalize = ['category_children clothes', 'category_handbags',
       'category_men clothes', 'category_men shoes', 'category_other',
       'category_soft', 'category_women clothes', 'category_women shoes',
       'color_cool_jewel', 'color_neutral_pastel', 'color_other',
       'color_vivid_metallic', 'color_warm_earth', 'season_autumn',
       'season_spring', 'season_summer', 'season_winter']

# %%
subset_to_normalize = data_women_model[columns_to_normalize]

# %%
sc = StandardScaler()

# %%
normalized_data = sc.fit_transform(subset_to_normalize)

# %%
data_women_model[columns_to_normalize] = normalized_data

# %%
data_women_model.head(3)
# Out:
#    residence_country 1  residence_country 2  residence_country 3  \
# 0                    1                    0                    0
# 1                    1                    0                    0
# 2                    1                    0                    0
#
#    residence_country 4  residence_country 5  residence_country 6  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
#
#    residence_country 7  residence_other region 1  residence_other region 2  \
# 0                    0                         0                         0
# 1                    0                         0                         0
# 2                    0                         0                         0
#
#    residence_other region 3  ...  category_women shoes  color_cool_jewel  \
# 0                         0  ...              0.284019         -0.815870
# 1                         0  ...              0.010956         -0.465336
# 2                         0  ...             -0.262107          1.988405
#
#    color_neutral_pastel  color_other  color_vivid_metallic  color_warm_earth  \
# 0             -0.955868    -0.493887             -0.703061         -0.612521
# 1             -0.329940    -0.493887             -0.087654         -0.431288
# 2              1.704327    -0.247338              2.373973          2.105975
#
#    season_autumn  season_spring  season_summer  season_winter
# 0      -0.178613      -0.679569      -0.845772      -0.825080
# 1      -0.877251      -0.511340       0.897134      -0.825080
# 2       0.170706       0.329804       0.548553       4.079763
#
# [3 rows x 36 columns]

# %% [markdown]
# ## Clustering | DBSCAN

# %%
#model 
dbscan = DBSCAN(eps=8,min_samples=10)

#fit
dbscan.fit(data_women_model)
# Out:
# DBSCAN(eps=8, min_samples=10)

# %%
# clusters
labels = dbscan.labels_

# %% [markdown]
# ### Clusters

# %%
data_women_model['Cluster'] = labels
data_women_model.head(3)
# Out:
#    residence_country 1  residence_country 2  residence_country 3  \
# 0                    1                    0                    0
# 1                    1                    0                    0
# 2                    1                    0                    0
#
#    residence_country 4  residence_country 5  residence_country 6  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
#
#    residence_country 7  residence_other region 1  residence_other region 2  \
# 0                    0                         0                         0
# 1                    0                         0                         0
# 2                    0                         0                         0
#
#    residence_other region 3  ...  color_cool_jewel  color_neutral_pastel  \
# 0                         0  ...         -0.815870             -0.955868
# 1                         0  ...         -0.465336             -0.329940
# 2                         0  ...          1.988405              1.704327
#
#    color_other  color_vivid_metallic  color_warm_earth  season_autumn  \
# 0    -0.493887             -0.703061         -0.612521      -0.178613
# 1    -0.493887             -0.087654         -0.431288      -0.877251
# 2    -0.247338              2.373973          2.105975       0.170706
#
#    season_spring  season_summer  season_winter  Cluster
# 0      -0.679569      -0.845772      -0.825080        0
# 1      -0.511340       0.897134      -0.825080        0
# 2       0.329804       0.548553       4.079763        0
#
# [3 rows x 37 columns]

# %% [markdown]
# ### Optimize hyperparameters

# %%
#hyperparameters to tune
eps_values = [6 , 7 , 8 , 9, 10]
min_samples_values = [5, 10, 15, 20, 25]

# %%
best_score = -1
best_eps = None
best_min_samples = None

# %%
for eps in eps_values:
    for min_samples in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(data_women_model)
        
        if len(set(labels)) > 1:  
            silhouette = metrics.silhouette_score(data_women_model, labels)
            
            if silhouette > best_score:
                best_score = silhouette
                best_eps = eps
                best_min_samples = min_samples

print(f"Best silhouette score: {best_score}")
print(f"Best eps: {best_eps}")
print(f"Best min_samples: {best_min_samples}")
# Out:
# Best silhouette score: 0.7114756286020424
# Best eps: 8
# Best min_samples: 20

# %% [markdown]
# ### Visualization

# %%
pca = PCA(2)

data_transformed = pd.DataFrame(pca.fit_transform(data_women_model), columns=["PC1","PC2"])
data_transformed.head(3)
# Out:
#         PC1       PC2
# 0 -2.328745 -0.245603
# 1 -1.290519  0.110760
# 2  4.571227  3.443371

# %% [markdown]
# ### Visualization

# %%
pca_plot = sns.scatterplot(x=data_transformed["PC1"],
                           y=data_transformed["PC2"],
                           hue=data_women_model["Cluster"],
                           palette="crest")
